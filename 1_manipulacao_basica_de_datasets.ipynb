# %% [markdown]
# # Manipulação Basica de Datasets

# %%
import pandas as pd

# %% [markdown]
# ###  Importanto/Carregando o Dataset
#
# Para carregar um dataset no formato csv, basta utilizar a função `read_csv` do pandas.

# %%
data = pd.read_csv("./datasets/gas_prices_brazil_2004-2021.csv")

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        09/05/2004  15/05/2004  CENTRO OESTE    DISTRITO FEDERAL
# 1        09/05/2004  15/05/2004  CENTRO OESTE               GOIAS
# 2        09/05/2004  15/05/2004  CENTRO OESTE         MATO GROSSO
# 3        09/05/2004  15/05/2004  CENTRO OESTE  MATO GROSSO DO SUL
# 4        09/05/2004  15/05/2004      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   25/04/2021  01/05/2021         NORTE             RORAIMA
# 120819   25/04/2021  01/05/2021           SUL      SANTA CATARINA
# 120820   25/04/2021  01/05/2021       SUDESTE           SAO PAULO
# 120821   25/04/2021  01/05/2021      NORDESTE             SERGIPE
# 120822   25/04/2021  01/05/2021         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 120818   OLEO DIESEL S10                            12              R$/l
# 120819   OLEO DIESEL S10                           100              R$/l
# 120820   OLEO DIESEL S10                           886              R$/l
# 120821   OLEO DIESEL S10                            33              R$/l
# 120822   OLEO DIESEL S10                            18              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 120818                4.582                  0.056                 4.510
# 120819                4.141                  0.187                 3.838
# 120820                4.246                  0.216                 3.769
# 120821                4.464                  0.205                 4.190
# 120822                4.352                  0.156                 4.199
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 120818                 4.690               -99999                     0.012
# 120819                 4.739               -99999                     0.045
# 120820                 5.199               -99999                     0.051
# 120821                 4.699               -99999                     0.046
# 120822                 4.699               -99999                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 120818                   -99999                     -99999
# 120819                   -99999                     -99999
# 120820                   -99999                     -99999
# 120821                   -99999                     -99999
# 120822                   -99999                     -99999
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 120818                    -99999                    -99999
# 120819                    -99999                    -99999
# 120820                    -99999                    -99999
# 120821                    -99999                    -99999
# 120822                    -99999                    -99999
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                              0.133
# 1                              0.115
# 2                              0.098
# 3                              0.143
# 4                              0.082
# ...                              ...
# 120818                        -99999
# 120819                        -99999
# 120820                        -99999
# 120821                        -99999
# 120822                        -99999
#
# [120823 rows x 18 columns]

# %% [markdown]
# ### Acessando Informações do DataFrame e Elementos Chave

# %% [markdown]
# #### Acessando as primeiras linhas

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   09/05/2004  15/05/2004  CENTRO OESTE    DISTRITO FEDERAL
# 1   09/05/2004  15/05/2004  CENTRO OESTE               GOIAS
# 2   09/05/2004  15/05/2004  CENTRO OESTE         MATO GROSSO
# 3   09/05/2004  15/05/2004  CENTRO OESTE  MATO GROSSO DO SUL
# 4   09/05/2004  15/05/2004      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                         0.133
# 1                         0.115
# 2                         0.098
# 3                         0.143
# 4                         0.082

# %%
data.head(2)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   09/05/2004  15/05/2004  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   09/05/2004  15/05/2004  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                    0.9666                         0.133
# 1                      1.05                         0.115

# %% [markdown]
# #### Informações Gerais Sobre o Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  object
#  1   DATA FINAL                     120823 non-null  object
#  2   REGIÃO                         120823 non-null  object
#  3   ESTADO                         120823 non-null  object
#  4   PRODUTO                        120823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  object
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           120823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       120823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       120823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     120823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      120823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      120823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  120823 non-null  object
# dtypes: float64(5), int64(1), object(12)
# memory usage: 16.6+ MB

# %% [markdown]
# #### DataFrame
#
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos. <br/>

# %% [markdown]
# No pandas, o objeto que representa o dataset carregado é chamado de Data Frame<br>
#
# É uma tabela bi-dimensional, de tamanho mutável, com dados parcialmente heterogêneos

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo `.shape` do Data Frame.

# %%
data.shape
# Out:
# (120823, 18)

# %% [markdown]
# ##### Criando um DataFrame

# %% [markdown]
# A forma mais comum é importar um DataFrame, porém também é possível criar um a partir de um dicionário.<br>
#
# As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
star_wars_dict = {
    "name": ["Luke Skywalker", "Yoda", "Palpatine"],
    "age": [16, 1000, 70],
    "weight_kg": [70, 15, 60],
    "is_jedi": [True, True, False]
}

star_wars = pd.DataFrame(star_wars_dict)
star_wars
# Out:
#              name   age  weight_kg  is_jedi
# 0  Luke Skywalker    16         70     True
# 1            Yoda  1000         15     True
# 2       Palpatine    70         60    False

# %% [markdown]
# ##### Renomeando Colunas

# %%
star_wars.columns
# Out:
# Index(['nome', 'age', 'weight_kg', 'is_jedi'], dtype='object')

# %%
type(star_wars.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
list(star_wars.columns)
# Out:
# ['nome', 'age', 'weight_kg', 'is_jedi']

# %% [markdown]
# Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma _cópia_ do data frame com as as colunas renomeadas:

# %%
cpsw = star_wars.rename(columns={
    "name": "full name"
}, inplace=True)

# %%
star_wars
# Out:
#         full name   age  weight_kg  is_jedi
# 0  Luke Skywalker    16         70     True
# 1            Yoda  1000         15     True
# 2       Palpatine    70         60    False

# %% [markdown]
# #### Series

# %% [markdown]
# Array uni-dimensional com os dados e rótulos de um eixo (linha ou coluna)

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   09/05/2004  15/05/2004  CENTRO OESTE    DISTRITO FEDERAL
# 1   09/05/2004  15/05/2004  CENTRO OESTE               GOIAS
# 2   09/05/2004  15/05/2004  CENTRO OESTE         MATO GROSSO
# 3   09/05/2004  15/05/2004  CENTRO OESTE  MATO GROSSO DO SUL
# 4   09/05/2004  15/05/2004      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                         0.133
# 1                         0.115
# 2                         0.098
# 3                         0.143
# 4                         0.082

# %%
# Selecionando uma coluna inteira

data["ESTADO"]
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: object

# %%
# Selecionando uma coluna inteira
# Esta forma só funciona para colunas sem espaços (ou qualquer outro caractere invalido)

data.ESTADO
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: object

# %%
type(data["ESTADO"])
# Out:
# pandas.core.series.Series

# %%
# Selecionando a observação indexada no index 1 do DataFrame

data.iloc[1]
# Out:
# DATA INICIAL                           09/05/2004
# DATA FINAL                             15/05/2004
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# Name: 1, dtype: object

# %%
type(data.iloc[1])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ##### Criando uma Series

# %%
pd.Series([5.5, 6.0, 12])
# Out:
# 0     5.5
# 1     6.0
# 2    12.0
# dtype: float64

# %% [markdown]
# #### Atribuindo Dados

# %% [markdown]
# ##### **Atribuindo constantes**

# %%
produto_view = data["PRODUTO"]
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 120818     OLEO DIESEL S10
# 120819     OLEO DIESEL S10
# 120820     OLEO DIESEL S10
# 120821     OLEO DIESEL S10
# 120822     OLEO DIESEL S10
# Name: PRODUTO, Length: 120823, dtype: object

# %%
produto_copy = data["PRODUTO"].copy()
produto_copy
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 120818     OLEO DIESEL S10
# 120819     OLEO DIESEL S10
# 120820     OLEO DIESEL S10
# 120821     OLEO DIESEL S10
# 120822     OLEO DIESEL S10
# Name: PRODUTO, Length: 120823, dtype: object

# %%
# gas["PRODUTO"] = "Combustível"
# Out:
# 'Combustível'

# %% [markdown]
# ##### **Atribuindo listas ou series**

# %%
nrows, ncols = data.shape
novos_produtos = [f"Produto {i}" for i in range(nrows)]
len(novos_produtos)
# Out:
# 120823

# %%
# gas["PRODUTO"] = novos_produtos

# %% [markdown]
# ##### **Criando novas colunas**

# %% [markdown]
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma _lista/Series de valores_ ou uma constante a uma **nova 'chave'** do data frame. <br/>
#
# **PS:** A _quantidade de valores_ da lista precisa ser **igual** ao _número de linhas/registros_ do data frame.

# %%
# Valor constante

data["COLUNA NOVA"] = "DEFAULT"

# %%
# A partir de uma lista

data["COLUNA A PARTIR DE LISTA"] = range(data.shape[0])

# %%
# Derivado de outras colunas

data["VALOR DERIVADO DE OUTRAS COLUNAS"] = data["PREÇO MÉDIO REVENDA"] * 6.0

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   09/05/2004  15/05/2004  CENTRO OESTE    DISTRITO FEDERAL
# 1   09/05/2004  15/05/2004  CENTRO OESTE               GOIAS
# 2   09/05/2004  15/05/2004  CENTRO OESTE         MATO GROSSO
# 3   09/05/2004  15/05/2004  CENTRO OESTE  MATO GROSSO DO SUL
# 4   09/05/2004  15/05/2004      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                     0.012                    0.825
# 1                     0.098                    0.763
# 2                     0.070                     0.97
# 3                     0.055                     0.83
# 4                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO coluna nova  \
# 0                    0.9666                         0.133     DEFAULT
# 1                      1.05                         0.115     DEFAULT
# 2                     1.161                         0.098     DEFAULT
# 3                   1.22242                         0.143     DEFAULT
# 4                    1.0317                         0.082     DEFAULT
#
#   COLUNA NOVA COLUNA A PARTIR DE LISTA VALOR DERIVADO DE OUTRAS COLUNAS
# 0     DEFAULT                        0                            7.728
# 1     DEFAULT                        1                            6.972
# 2     DEFAULT                        2                            8.334
# 3     DEFAULT                        3                            7.572
# 4     DEFAULT                        4                            7.086
#
# [5 rows x 22 columns]

# %% [markdown]
# ##### **Index**

# %% [markdown]
# Todo Data Frame possui **índices**, que não são considerado colunas da tabela. Tais índices são comumente **númericos**, de 0 a num_linhas-1, mas também podem ser **textuais (rótulos/labels)**.|

# %%
data.index
# Out:
# RangeIndex(start=0, stop=120823, step=1)

# %% [markdown]
# Use `list(data.index)` ou `data.index.to_list()` para converter um RangeIndex para uma python list.

# %%
#### Exemplo de Data Frame com Índices Textuais (labels)

pesquisa_de_satisfacao = pd.DataFrame({
    "bom": [50, 21, 100],
    "ruim": [131, 2, 30],
    "pessimo": [30, 20, 1]
}, index=["Xbox", "PS5", "Switch"])

# %%
pesquisa_de_satisfacao
# Out:
#         bom  ruim  pessimo
# Xbox     50   131       30
# PS5      21     2       20
# Switch  100    30        1

# %% [markdown]
# #### Selecionando uma ou mais linhas/observações (indexação)

# %%
data.head(3)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   09/05/2004  15/05/2004  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   09/05/2004  15/05/2004  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   09/05/2004  15/05/2004  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
# 2                0.419                     0.070                     0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                    0.9666                         0.133
# 1                      1.05                         0.115
# 2                     1.161                         0.098

# %% [markdown]
# ##### **Index-based selection (seleção baseadas em Rótulos)**

# %% [markdown]
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do Dataframe, baseado em seu **índice (número)** --> row-first, column-second
# - `iloc[row, col]`

# %% [markdown]
# ###### **Selecionando uma linha/observação:**

# %%
# Selecionando a linha 1 - observação de index 1 do DataFrame
data.iloc[1]
# Out:
# DATA INICIAL                           09/05/2004
# DATA FINAL                             15/05/2004
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# Name: 1, dtype: object

# %% [markdown]
# ###### **Selecionando múltiplas linhas/observações:**

# %%
# Selecionando as linhas de index de 0 a 5 (slice, continuo)
data.iloc[:6]
data.iloc[12:22]
# Out:
#    DATA INICIAL  DATA FINAL    REGIÃO          ESTADO           PRODUTO  \
# 12   09/05/2004  15/05/2004  NORDESTE         SERGIPE  ETANOL HIDRATADO
# 13   09/05/2004  15/05/2004     NORTE            ACRE  ETANOL HIDRATADO
# 14   09/05/2004  15/05/2004     NORTE           AMAPA  ETANOL HIDRATADO
# 15   09/05/2004  15/05/2004     NORTE        AMAZONAS  ETANOL HIDRATADO
# 16   09/05/2004  15/05/2004     NORTE            PARA  ETANOL HIDRATADO
# 17   09/05/2004  15/05/2004     NORTE        RONDONIA  ETANOL HIDRATADO
# 18   09/05/2004  15/05/2004     NORTE         RORAIMA  ETANOL HIDRATADO
# 19   09/05/2004  15/05/2004     NORTE       TOCANTINS  ETANOL HIDRATADO
# 20   09/05/2004  15/05/2004   SUDESTE  ESPIRITO SANTO  ETANOL HIDRATADO
# 21   09/05/2004  15/05/2004   SUDESTE    MINAS GERAIS  ETANOL HIDRATADO
#
#     NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12                            57              R$/l                1.301
# 13                            33              R$/l                1.805
# 14                            15              R$/l                1.785
# 15                            53              R$/l                1.578
# 16                           104              R$/l                1.914
# 17                            97              R$/l                1.545
# 18                            14              R$/l                1.300
# 19                            71              R$/l                1.226
# 20                           306              R$/l                1.148
# 21                          1238              R$/l                1.205
#
#     DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 12                  0.109                  1.15                 1.750
# 13                  0.134                  1.50                 1.980
# 14                  0.035                  1.74                 1.850
# 15                  0.123                  1.28                 1.850
# 16                  0.246                  1.27                 2.400
# 17                  0.141                  1.25                 1.990
# 18                  0.000                  1.30                 1.300
# 19                  0.081                  1.05                 1.430
# 20                  0.116                  0.89                 1.490
# 21                  0.120                  0.92                 1.875
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 12                0.321                     0.084                     0.98
# 13                0.689                     0.074                    1.116
# 14                0.412                     0.020                    1.373
# 15                0.441                     0.078                    1.137
# 16                0.536                     0.129                    1.378
# 17                0.533                     0.091                    1.012
# 18                0.202                     0.000                    1.098
# 19                0.546                     0.066                     0.68
# 20                0.267                     0.101                    0.881
# 21                0.389                     0.100                    0.816
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 12                      0.052                    0.8267
# 13                      0.171                     0.767
# 14                      0.167                    0.8339
# 15                      0.068                    0.9515
# 16                      0.237                    0.7564
# 17                      0.149                      0.52
# 18                      0.096                    0.9798
# 19                      0.114                   0.51022
# 20                      0.095                    0.6259
# 21                      0.123                    0.3797
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 12                    1.1059                         0.053
# 13                    1.2992                         0.153
# 14                    1.4912                         0.122
# 15                    1.2109                          0.06
# 16                    1.8908                         0.172
# 17                    1.3306                         0.147
# 18                    1.3577                         0.087
# 19                     1.035                         0.168
# 20                    1.1381                         0.108
# 21                     1.437                         0.151

# %%
# Selecionar as linhas de index 1, 5, 10 e 15 (isoladamente, ordem não importa)
data.iloc[[1, 5, 10, 15]]
# Out:
#    DATA INICIAL  DATA FINAL        REGIÃO    ESTADO           PRODUTO  \
# 1    09/05/2004  15/05/2004  CENTRO OESTE     GOIAS  ETANOL HIDRATADO
# 5    09/05/2004  15/05/2004      NORDESTE     BAHIA  ETANOL HIDRATADO
# 10   09/05/2004  15/05/2004      NORDESTE     PIAUI  ETANOL HIDRATADO
# 15   09/05/2004  15/05/2004         NORTE  AMAZONAS  ETANOL HIDRATADO
#
#     NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1                            387              R$/l                1.162
# 5                            408              R$/l                1.383
# 10                            89              R$/l                1.573
# 15                            53              R$/l                1.578
#
#     DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 1                   0.114                 0.890                 1.449
# 5                   0.132                 0.999                 2.050
# 10                  0.134                 1.400                 1.780
# 15                  0.123                 1.280                 1.850
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                 0.399                     0.098                    0.763
# 5                 0.426                     0.095                    0.957
# 10                0.494                     0.085                    1.079
# 15                0.441                     0.078                    1.137
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1                       0.088                    0.5013
# 5                       0.128                    0.5686
# 10                      0.078                    0.8857
# 15                      0.068                    0.9515
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 1                       1.05                         0.115
# 5                       1.35                         0.134
# 10                    1.2499                         0.072
# 15                    1.2109                          0.06

# %%
# Selecionar um valor baseado no index e coluna
# index 1, coluna 2 ("REGIÃO")
data.iloc[1, 2]
# Out:
# 'CENTRO OESTE'

# %% [markdown]
# ##### **Label-based selection (seleção baseada em rótulos)**

# %% [markdown]
# `loc`: seleciona elementos do Dataframe, baseado em seus **rótulos** --> row-first, column-second
# - `loc[row, col]`

# %%
pesquisa_de_satisfacao
# Out:
#         bom  ruim  pessimo
# Xbox     50   131       30
# PS5      21     2       20
# Switch  100    30        1

# %%
# Index rotoluado é implicitamente um número
pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: Xbox, dtype: int64

# %%
# Busca pelo nome da label
pesquisa_de_satisfacao.loc["Xbox"]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: Xbox, dtype: int64

# %%
pesquisa_de_satisfacao.loc["PS5", "ruim"]
# Out:
# 2

# %%
pesquisa_de_satisfacao.loc[["Xbox", "PS5"], ["bom", "pessimo"]]
# Out:
#       bom  pessimo
# Xbox   50       30
# PS5    21       20

# %%
pesquisa_de_satisfacao.loc[:, ["bom", "pessimo"]]
# Out:
#         bom  pessimo
# Xbox     50       30
# PS5      21       20
# Switch  100        1

# %% [markdown]
# #### Selecionando uma ou mais Colunas/Features

# %%
data.head(3)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   09/05/2004  15/05/2004  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   09/05/2004  15/05/2004  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   09/05/2004  15/05/2004  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
# 2                0.419                     0.070                     0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                    0.9666                         0.133
# 1                      1.05                         0.115
# 2                     1.161                         0.098

# %%
# Retornando uma coluna
data["ESTADO"]
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: object

# %%
data.ESTADO
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: object

# %%
data[["ESTADO", "REGIÃO"]]
# Out:
#                     ESTADO        REGIÃO
# 0         DISTRITO FEDERAL  CENTRO OESTE
# 1                    GOIAS  CENTRO OESTE
# 2              MATO GROSSO  CENTRO OESTE
# 3       MATO GROSSO DO SUL  CENTRO OESTE
# 4                  ALAGOAS      NORDESTE
# ...                    ...           ...
# 120818             RORAIMA         NORTE
# 120819      SANTA CATARINA           SUL
# 120820           SAO PAULO       SUDESTE
# 120821             SERGIPE      NORDESTE
# 120822           TOCANTINS         NORTE
#
# [120823 rows x 2 columns]

# %%
data.loc[:, "ESTADO"]
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: object

# %% [markdown]
# #### Removendo uma Coluna/Feature do DataFrame

# %%
data.head(1)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   09/05/2004  15/05/2004  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 0                  0.016                  1.19  ...                 0.463
#
#   COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                    0.012                     0.825
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO COLUNA NOVA  \
# 0                    0.9666                         0.133     DEFAULT
#
#   COLUNA A PARTIR DE LISTA  VALOR DERIVADO DE OUTRAS COLUNAS
# 0                        0                             7.728
#
# [1 rows x 21 columns]

# %%
# deleta/remove in-place

del data["COLUNA NOVA"]

# %%
data.head(1)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   09/05/2004  15/05/2004  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                  1.35
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  \
# 0                    0.9666                         0.133
#
#    COLUNA A PARTIR DE LISTA  VALOR DERIVADO DE OUTRAS COLUNAS
# 0                         0                             7.728

# %%
del data["COLUNA A PARTIR DE LISTA"]
del data["VALOR DERIVADO DE OUTRAS COLUNAS"]

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [DATA INICIAL, DATA FINAL, REGIÃO, ESTADO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO]
# Index: []

# %% [markdown]
# #### Salvando um DataFrame

# %% [markdown]
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `.to_csv`. <br/>
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.<br/>
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso.<br/>
# Desta forma, utilize o parâmetro: `index=False`.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
data.to_csv('./datasets/gas_prices_brazil_2004-2021.csv', index=False)

# %% [markdown]
# ##### **Selecionando apenas o preço dos postos de São Paulo**

# %% [markdown]
# #### Seleção Condicional: Filtrando Linhas/Observações

# %% [markdown]
# Durante nossas análise exploratórias, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de análise mais específica. <br/>
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso dataset pré-processado que salvamos no item anterior.

# %%
# Unique() retorna um array com os valores unicos possíveis
data["ESTADO"].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %% [markdown]
# ##### **Seleção Condicional**

# %% [markdown]
# Faz uma comparação elemento a elemento e retorna uma nova ***Series ('array') de booleans*** com o resultado das comparações.

# %%
data["ESTADO"] == "SAO PAULO"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 120818    False
# 120819    False
# 120820     True
# 120821    False
# 120822    False
# Name: ESTADO, Length: 120823, dtype: bool

# %%
estado_sp = data["ESTADO"] == "SAO PAULO"

# %%
# O resultado é um DataFrame NOVO só com os dados filtrados

data[estado_sp]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       09/05/2004  15/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       16/05/2004  22/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       23/05/2004  29/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      30/05/2004  05/06/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      06/06/2004  12/06/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 120723   25/04/2021  01/05/2021  SUDESTE  SAO PAULO    GASOLINA COMUM
# 120750   25/04/2021  01/05/2021  SUDESTE  SAO PAULO               GLP
# 120767   25/04/2021  01/05/2021  SUDESTE  SAO PAULO               GNV
# 120793   25/04/2021  01/05/2021  SUDESTE  SAO PAULO       OLEO DIESEL
# 120820   25/04/2021  01/05/2021  SUDESTE  SAO PAULO   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 120723                          1187              R$/l                5.265
# 120750                           663           R$/13Kg               85.340
# 120767                            51             R$/m3                3.150
# 120793                           411              R$/l                4.134
# 120820                           886              R$/l                4.246
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 23                      0.085                 0.590                 1.150
# 50                      0.083                 0.590                 1.150
# 77                      0.071                 0.620                 1.199
# 104                     0.075                 0.639                 1.359
# 131                     0.071                 0.669                 1.199
# ...                       ...                   ...                   ...
# 120723                  0.218                 4.279                 6.099
# 120750                  5.292                68.000                99.990
# 120767                  0.282                 2.499                 3.797
# 120793                  0.188                 3.699                 5.099
# 120820                  0.216                 3.769                 5.199
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                    0.198                     0.111
# 50                     0.19                     0.108
# 77                    0.209                     0.086
# 104                   0.216                     0.085
# 131                   0.205                     0.079
# ...                     ...                       ...
# 120723               -99999                     0.041
# 120750               -99999                     0.062
# 120767               -99999                     0.090
# 120793               -99999                     0.045
# 120820               -99999                     0.051
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.57                      0.056
# 50                        0.576                       0.05
# 77                        0.614                      0.063
# 104                       0.671                      0.075
# 131                       0.689                      0.072
# ...                         ...                        ...
# 120723                   -99999                     -99999
# 120750                   -99999                     -99999
# 120767                   -99999                     -99999
# 120793                   -99999                     -99999
# 120820                   -99999                     -99999
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 120723                    -99999                    -99999
# 120750                    -99999                    -99999
# 120767                    -99999                    -99999
# 120793                    -99999                    -99999
# 120820                    -99999                    -99999
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 23                             0.098
# 50                             0.087
# 77                             0.103
# 104                            0.112
# 131                            0.104
# ...                              ...
# 120723                        -99999
# 120750                        -99999
# 120767                        -99999
# 120793                        -99999
# 120820                        -99999
#
# [4819 rows x 18 columns]

# %%
data.loc[estado_sp]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       09/05/2004  15/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       16/05/2004  22/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       23/05/2004  29/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      30/05/2004  05/06/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      06/06/2004  12/06/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 120723   25/04/2021  01/05/2021  SUDESTE  SAO PAULO    GASOLINA COMUM
# 120750   25/04/2021  01/05/2021  SUDESTE  SAO PAULO               GLP
# 120767   25/04/2021  01/05/2021  SUDESTE  SAO PAULO               GNV
# 120793   25/04/2021  01/05/2021  SUDESTE  SAO PAULO       OLEO DIESEL
# 120820   25/04/2021  01/05/2021  SUDESTE  SAO PAULO   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 120723                          1187              R$/l                5.265
# 120750                           663           R$/13Kg               85.340
# 120767                            51             R$/m3                3.150
# 120793                           411              R$/l                4.134
# 120820                           886              R$/l                4.246
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 23                      0.085                 0.590                 1.150
# 50                      0.083                 0.590                 1.150
# 77                      0.071                 0.620                 1.199
# 104                     0.075                 0.639                 1.359
# 131                     0.071                 0.669                 1.199
# ...                       ...                   ...                   ...
# 120723                  0.218                 4.279                 6.099
# 120750                  5.292                68.000                99.990
# 120767                  0.282                 2.499                 3.797
# 120793                  0.188                 3.699                 5.099
# 120820                  0.216                 3.769                 5.199
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                    0.198                     0.111
# 50                     0.19                     0.108
# 77                    0.209                     0.086
# 104                   0.216                     0.085
# 131                   0.205                     0.079
# ...                     ...                       ...
# 120723               -99999                     0.041
# 120750               -99999                     0.062
# 120767               -99999                     0.090
# 120793               -99999                     0.045
# 120820               -99999                     0.051
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.57                      0.056
# 50                        0.576                       0.05
# 77                        0.614                      0.063
# 104                       0.671                      0.075
# 131                       0.689                      0.072
# ...                         ...                        ...
# 120723                   -99999                     -99999
# 120750                   -99999                     -99999
# 120767                   -99999                     -99999
# 120793                   -99999                     -99999
# 120820                   -99999                     -99999
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 120723                    -99999                    -99999
# 120750                    -99999                    -99999
# 120767                    -99999                    -99999
# 120793                    -99999                    -99999
# 120820                    -99999                    -99999
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 23                             0.098
# 50                             0.087
# 77                             0.103
# 104                            0.112
# 131                            0.104
# ...                              ...
# 120723                        -99999
# 120750                        -99999
# 120767                        -99999
# 120793                        -99999
# 120820                        -99999
#
# [4819 rows x 18 columns]

# %% [markdown]
# ##### **Utilizando o Método query()**

# %% [markdown]
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**.
# - Retorna um DataFrame (filtrado)

# %%
data.query("ESTADO == 'SAO PAULO'")
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       09/05/2004  15/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       16/05/2004  22/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       23/05/2004  29/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      30/05/2004  05/06/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      06/06/2004  12/06/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 120723   25/04/2021  01/05/2021  SUDESTE  SAO PAULO    GASOLINA COMUM
# 120750   25/04/2021  01/05/2021  SUDESTE  SAO PAULO               GLP
# 120767   25/04/2021  01/05/2021  SUDESTE  SAO PAULO               GNV
# 120793   25/04/2021  01/05/2021  SUDESTE  SAO PAULO       OLEO DIESEL
# 120820   25/04/2021  01/05/2021  SUDESTE  SAO PAULO   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 120723                          1187              R$/l                5.265
# 120750                           663           R$/13Kg               85.340
# 120767                            51             R$/m3                3.150
# 120793                           411              R$/l                4.134
# 120820                           886              R$/l                4.246
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 23                      0.085                 0.590                 1.150
# 50                      0.083                 0.590                 1.150
# 77                      0.071                 0.620                 1.199
# 104                     0.075                 0.639                 1.359
# 131                     0.071                 0.669                 1.199
# ...                       ...                   ...                   ...
# 120723                  0.218                 4.279                 6.099
# 120750                  5.292                68.000                99.990
# 120767                  0.282                 2.499                 3.797
# 120793                  0.188                 3.699                 5.099
# 120820                  0.216                 3.769                 5.199
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                    0.198                     0.111
# 50                     0.19                     0.108
# 77                    0.209                     0.086
# 104                   0.216                     0.085
# 131                   0.205                     0.079
# ...                     ...                       ...
# 120723               -99999                     0.041
# 120750               -99999                     0.062
# 120767               -99999                     0.090
# 120793               -99999                     0.045
# 120820               -99999                     0.051
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.57                      0.056
# 50                        0.576                       0.05
# 77                        0.614                      0.063
# 104                       0.671                      0.075
# 131                       0.689                      0.072
# ...                         ...                        ...
# 120723                   -99999                     -99999
# 120750                   -99999                     -99999
# 120767                   -99999                     -99999
# 120793                   -99999                     -99999
# 120820                   -99999                     -99999
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 120723                    -99999                    -99999
# 120750                    -99999                    -99999
# 120767                    -99999                    -99999
# 120793                    -99999                    -99999
# 120820                    -99999                    -99999
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 23                             0.098
# 50                             0.087
# 77                             0.103
# 104                            0.112
# 131                            0.104
# ...                              ...
# 120723                        -99999
# 120750                        -99999
# 120767                        -99999
# 120793                        -99999
# 120820                        -99999
#
# [4819 rows x 18 columns]

# %%
postos_sp = data.query("ESTADO == 'SAO PAULO'")
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       09/05/2004  15/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       16/05/2004  22/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       23/05/2004  29/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      30/05/2004  05/06/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      06/06/2004  12/06/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 120723   25/04/2021  01/05/2021  SUDESTE  SAO PAULO    GASOLINA COMUM
# 120750   25/04/2021  01/05/2021  SUDESTE  SAO PAULO               GLP
# 120767   25/04/2021  01/05/2021  SUDESTE  SAO PAULO               GNV
# 120793   25/04/2021  01/05/2021  SUDESTE  SAO PAULO       OLEO DIESEL
# 120820   25/04/2021  01/05/2021  SUDESTE  SAO PAULO   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 120723                          1187              R$/l                5.265
# 120750                           663           R$/13Kg               85.340
# 120767                            51             R$/m3                3.150
# 120793                           411              R$/l                4.134
# 120820                           886              R$/l                4.246
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 23                      0.085                 0.590                 1.150
# 50                      0.083                 0.590                 1.150
# 77                      0.071                 0.620                 1.199
# 104                     0.075                 0.639                 1.359
# 131                     0.071                 0.669                 1.199
# ...                       ...                   ...                   ...
# 120723                  0.218                 4.279                 6.099
# 120750                  5.292                68.000                99.990
# 120767                  0.282                 2.499                 3.797
# 120793                  0.188                 3.699                 5.099
# 120820                  0.216                 3.769                 5.199
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                    0.198                     0.111
# 50                     0.19                     0.108
# 77                    0.209                     0.086
# 104                   0.216                     0.085
# 131                   0.205                     0.079
# ...                     ...                       ...
# 120723               -99999                     0.041
# 120750               -99999                     0.062
# 120767               -99999                     0.090
# 120793               -99999                     0.045
# 120820               -99999                     0.051
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.57                      0.056
# 50                        0.576                       0.05
# 77                        0.614                      0.063
# 104                       0.671                      0.075
# 131                       0.689                      0.072
# ...                         ...                        ...
# 120723                   -99999                     -99999
# 120750                   -99999                     -99999
# 120767                   -99999                     -99999
# 120793                   -99999                     -99999
# 120820                   -99999                     -99999
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 120723                    -99999                    -99999
# 120750                    -99999                    -99999
# 120767                    -99999                    -99999
# 120793                    -99999                    -99999
# 120820                    -99999                    -99999
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 23                             0.098
# 50                             0.087
# 77                             0.103
# 104                            0.112
# 131                            0.104
# ...                              ...
# 120723                        -99999
# 120750                        -99999
# 120767                        -99999
# 120793                        -99999
# 120820                        -99999
#
# [4819 rows x 18 columns]

# %%
type(postos_sp)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Note que os _índices das linhas/registros_ após a _filtragem_ **continuam sendo os mesmos** do DataFrame original. <br/>
# Em muitas situações, manter esta informação será importante.
#
# Mas, se você quiser **_resetar os índices_** do data frame filtrado, fazendo com que os registros começem com _índice 0 até num_linhas-1_, use o método `.reset_index`.

# %%
postos_sp.reset_index()
# Out:
#        index DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0         23   09/05/2004  15/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1         50   16/05/2004  22/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2         77   23/05/2004  29/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3        104   30/05/2004  05/06/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4        131   06/06/2004  12/06/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...      ...          ...         ...      ...        ...               ...
# 4814  120723   25/04/2021  01/05/2021  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4815  120750   25/04/2021  01/05/2021  SUDESTE  SAO PAULO               GLP
# 4816  120767   25/04/2021  01/05/2021  SUDESTE  SAO PAULO               GNV
# 4817  120793   25/04/2021  01/05/2021  SUDESTE  SAO PAULO       OLEO DIESEL
# 4818  120820   25/04/2021  01/05/2021  SUDESTE  SAO PAULO   OLEO DIESEL S10
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4814                          1187              R$/l                5.265
# 4815                           663           R$/13Kg               85.340
# 4816                            51             R$/m3                3.150
# 4817                           411              R$/l                4.134
# 4818                           886              R$/l                4.246
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                     0.085                 0.590                 1.150
# 1                     0.083                 0.590                 1.150
# 2                     0.071                 0.620                 1.199
# 3                     0.075                 0.639                 1.359
# 4                     0.071                 0.669                 1.199
# ...                     ...                   ...                   ...
# 4814                  0.218                 4.279                 6.099
# 4815                  5.292                68.000                99.990
# 4816                  0.282                 2.499                 3.797
# 4817                  0.188                 3.699                 5.099
# 4818                  0.216                 3.769                 5.199
#
#      MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                   0.198                     0.111                     0.57
# 1                    0.19                     0.108                    0.576
# 2                   0.209                     0.086                    0.614
# 3                   0.216                     0.085                    0.671
# 4                   0.205                     0.079                    0.689
# ...                   ...                       ...                      ...
# 4814               -99999                     0.041                   -99999
# 4815               -99999                     0.062                   -99999
# 4816               -99999                     0.090                   -99999
# 4817               -99999                     0.045                   -99999
# 4818               -99999                     0.051                   -99999
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.056                    0.4271
# 1                          0.05                   0.43204
# 2                         0.063                   0.34951
# 3                         0.075                    0.3398
# 4                         0.072                   0.47797
# ...                         ...                       ...
# 4814                     -99999                    -99999
# 4815                     -99999                    -99999
# 4816                     -99999                    -99999
# 4817                     -99999                    -99999
# 4818                     -99999                    -99999
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                       1.4123                         0.098
# 1                       0.9724                         0.087
# 2                        1.412                         0.103
# 3                       1.0669                         0.112
# 4                       1.0669                         0.104
# ...                        ...                           ...
# 4814                    -99999                        -99999
# 4815                    -99999                        -99999
# 4816                    -99999                        -99999
# 4817                    -99999                        -99999
# 4818                    -99999                        -99999
#
# [4819 rows x 19 columns]

# %%
postos_sp.reset_index(drop=True, inplace=True)
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      09/05/2004  15/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      16/05/2004  22/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      23/05/2004  29/05/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      30/05/2004  05/06/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      06/06/2004  12/06/2004  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4814   25/04/2021  01/05/2021  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4815   25/04/2021  01/05/2021  SUDESTE  SAO PAULO               GLP
# 4816   25/04/2021  01/05/2021  SUDESTE  SAO PAULO               GNV
# 4817   25/04/2021  01/05/2021  SUDESTE  SAO PAULO       OLEO DIESEL
# 4818   25/04/2021  01/05/2021  SUDESTE  SAO PAULO   OLEO DIESEL S10
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4814                          1187              R$/l                5.265
# 4815                           663           R$/13Kg               85.340
# 4816                            51             R$/m3                3.150
# 4817                           411              R$/l                4.134
# 4818                           886              R$/l                4.246
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                     0.085                 0.590                 1.150
# 1                     0.083                 0.590                 1.150
# 2                     0.071                 0.620                 1.199
# 3                     0.075                 0.639                 1.359
# 4                     0.071                 0.669                 1.199
# ...                     ...                   ...                   ...
# 4814                  0.218                 4.279                 6.099
# 4815                  5.292                68.000                99.990
# 4816                  0.282                 2.499                 3.797
# 4817                  0.188                 3.699                 5.099
# 4818                  0.216                 3.769                 5.199
#
#      MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                   0.198                     0.111                     0.57
# 1                    0.19                     0.108                    0.576
# 2                   0.209                     0.086                    0.614
# 3                   0.216                     0.085                    0.671
# 4                   0.205                     0.079                    0.689
# ...                   ...                       ...                      ...
# 4814               -99999                     0.041                   -99999
# 4815               -99999                     0.062                   -99999
# 4816               -99999                     0.090                   -99999
# 4817               -99999                     0.045                   -99999
# 4818               -99999                     0.051                   -99999
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.056                    0.4271
# 1                          0.05                   0.43204
# 2                         0.063                   0.34951
# 3                         0.075                    0.3398
# 4                         0.072                   0.47797
# ...                         ...                       ...
# 4814                     -99999                    -99999
# 4815                     -99999                    -99999
# 4816                     -99999                    -99999
# 4817                     -99999                    -99999
# 4818                     -99999                    -99999
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                       1.4123                         0.098
# 1                       0.9724                         0.087
# 2                        1.412                         0.103
# 3                       1.0669                         0.112
# 4                       1.0669                         0.104
# ...                        ...                           ...
# 4814                    -99999                        -99999
# 4815                    -99999                        -99999
# 4816                    -99999                        -99999
# 4817                    -99999                        -99999
# 4818                    -99999                        -99999
#
# [4819 rows x 18 columns]

# %% [markdown]
# ##### **Aprofundando com Filtros Condicionais**

# %%
data.head(3)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   09/05/2004  15/05/2004  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   09/05/2004  15/05/2004  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   09/05/2004  15/05/2004  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
# 2                0.419                     0.070                     0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                    0.9666                         0.133
# 1                      1.05                         0.115
# 2                     1.161                         0.098

# %%
estado_rj_preco_maior_que_2 = (data["ESTADO"] == "RIO DE JANEIRO") & (data["PREÇO MÉDIO REVENDA"] > 2)
estado_rj_preco_maior_que_2
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 120818    False
# 120819    False
# 120820    False
# 120821    False
# 120822    False
# Length: 120823, dtype: bool

# %%
data[estado_rj_preco_maior_que_2]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     26/02/2006  04/03/2006  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     05/03/2006  11/03/2006  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     12/03/2006  18/03/2006  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     19/03/2006  25/03/2006  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     26/03/2006  01/04/2006  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 120717   25/04/2021  01/05/2021  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 120744   25/04/2021  01/05/2021  SUDESTE  RIO DE JANEIRO               GLP
# 120763   25/04/2021  01/05/2021  SUDESTE  RIO DE JANEIRO               GNV
# 120787   25/04/2021  01/05/2021  SUDESTE  RIO DE JANEIRO       OLEO DIESEL
# 120814   25/04/2021  01/05/2021  SUDESTE  RIO DE JANEIRO   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 2501                             881              R$/l                2.028
# 2528                             889              R$/l                2.125
# 2555                             902              R$/l                2.163
# 2582                             898              R$/l                2.166
# 2609                             890              R$/l                2.172
# ...                              ...               ...                  ...
# 120717                           198              R$/l                6.099
# 120744                           137           R$/13Kg               75.218
# 120763                            77             R$/m3                3.011
# 120787                            72              R$/l                4.290
# 120814                           155              R$/l                4.302
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 2501                    0.148                 1.589                 2.550
# 2528                    0.149                 1.779                 2.550
# 2555                    0.138                 1.799                 2.599
# 2582                    0.146                 1.760                 2.568
# 2609                    0.143                 1.789                 2.550
# ...                       ...                   ...                   ...
# 120717                  0.208                 5.480                 6.599
# 120744                  5.398                65.000                93.000
# 120763                  0.385                 2.759                 4.399
# 120787                  0.183                 3.849                 4.599
# 120814                  0.172                 3.930                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 2501                  0.222                     0.073
# 2528                  0.286                     0.070
# 2555                  0.268                     0.064
# 2582                  0.231                     0.067
# 2609                  0.209                     0.066
# ...                     ...                       ...
# 120717               -99999                     0.034
# 120744               -99999                     0.072
# 120763               -99999                     0.128
# 120787               -99999                     0.043
# 120814               -99999                     0.040
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 2501                      1.806                       0.11
# 2528                      1.839                      0.117
# 2555                      1.895                      0.134
# 2582                      1.935                       0.14
# 2609                      1.963                      0.133
# ...                         ...                        ...
# 120717                   -99999                     -99999
# 120744                   -99999                     -99999
# 120763                   -99999                     -99999
# 120787                   -99999                     -99999
# 120814                   -99999                     -99999
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 2501                        1.31                    2.1358
# 2528                       1.438                    2.2801
# 2555                        1.43                    2.3454
# 2582                       1.438                    2.2925
# 2609                       1.438                    2.2513
# ...                          ...                       ...
# 120717                    -99999                    -99999
# 120744                    -99999                    -99999
# 120763                    -99999                    -99999
# 120787                    -99999                    -99999
# 120814                    -99999                    -99999
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 2501                           0.061
# 2528                           0.064
# 2555                           0.071
# 2582                           0.072
# 2609                           0.068
# ...                              ...
# 120717                        -99999
# 120744                        -99999
# 120763                        -99999
# 120787                        -99999
# 120814                        -99999
#
# [3610 rows x 18 columns]

# %% [markdown]
# O resultado da seleção continua sendo uma Series de booleans com o mesmo número de linhas/observações do DataFrame, de modo que cada linha possuirá um valor booleano indicando se as comparações resultaram TRUE ou FALSE.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&).
# Similarmente:
#
# **|** representa o **OR** (não é ||)
# **~** representa o **NOT** (não é !)

# %% [markdown]
# **Falando Sobre Eficiência**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (observação a observação) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2)` checa, linha a linha (observação a observação) do DataFrame, quais são os registros cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.

# %% [markdown]
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. <br/>
# O Pandas _tenta otimizar_ isso ao máximo por de trás dos panos. Mas, de fato, se tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará _lenta_.

# %% [markdown]
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %%
estados_rj = data["ESTADO"] == "RIO DE JANEIRO"

# %%
postos_rj = data[estados_rj]

# %%
preco_maior_que_2 = postos_rj["PREÇO MÉDIO REVENDA"] > 2

# %%
postos_rj_com_preco_maior_que_2 = postos_rj[preco_maior_que_2]

# %%
postos_rj_com_preco_maior_que_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     26/02/2006  04/03/2006  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     05/03/2006  11/03/2006  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     12/03/2006  18/03/2006  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     19/03/2006  25/03/2006  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     26/03/2006  01/04/2006  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 120717   25/04/2021  01/05/2021  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 120744   25/04/2021  01/05/2021  SUDESTE  RIO DE JANEIRO               GLP
# 120763   25/04/2021  01/05/2021  SUDESTE  RIO DE JANEIRO               GNV
# 120787   25/04/2021  01/05/2021  SUDESTE  RIO DE JANEIRO       OLEO DIESEL
# 120814   25/04/2021  01/05/2021  SUDESTE  RIO DE JANEIRO   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 2501                             881              R$/l                2.028
# 2528                             889              R$/l                2.125
# 2555                             902              R$/l                2.163
# 2582                             898              R$/l                2.166
# 2609                             890              R$/l                2.172
# ...                              ...               ...                  ...
# 120717                           198              R$/l                6.099
# 120744                           137           R$/13Kg               75.218
# 120763                            77             R$/m3                3.011
# 120787                            72              R$/l                4.290
# 120814                           155              R$/l                4.302
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 2501                    0.148                 1.589                 2.550
# 2528                    0.149                 1.779                 2.550
# 2555                    0.138                 1.799                 2.599
# 2582                    0.146                 1.760                 2.568
# 2609                    0.143                 1.789                 2.550
# ...                       ...                   ...                   ...
# 120717                  0.208                 5.480                 6.599
# 120744                  5.398                65.000                93.000
# 120763                  0.385                 2.759                 4.399
# 120787                  0.183                 3.849                 4.599
# 120814                  0.172                 3.930                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 2501                  0.222                     0.073
# 2528                  0.286                     0.070
# 2555                  0.268                     0.064
# 2582                  0.231                     0.067
# 2609                  0.209                     0.066
# ...                     ...                       ...
# 120717               -99999                     0.034
# 120744               -99999                     0.072
# 120763               -99999                     0.128
# 120787               -99999                     0.043
# 120814               -99999                     0.040
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 2501                      1.806                       0.11
# 2528                      1.839                      0.117
# 2555                      1.895                      0.134
# 2582                      1.935                       0.14
# 2609                      1.963                      0.133
# ...                         ...                        ...
# 120717                   -99999                     -99999
# 120744                   -99999                     -99999
# 120763                   -99999                     -99999
# 120787                   -99999                     -99999
# 120814                   -99999                     -99999
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 2501                        1.31                    2.1358
# 2528                       1.438                    2.2801
# 2555                        1.43                    2.3454
# 2582                       1.438                    2.2925
# 2609                       1.438                    2.2513
# ...                          ...                       ...
# 120717                    -99999                    -99999
# 120744                    -99999                    -99999
# 120763                    -99999                    -99999
# 120787                    -99999                    -99999
# 120814                    -99999                    -99999
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 2501                           0.061
# 2528                           0.064
# 2555                           0.071
# 2582                           0.072
# 2609                           0.068
# ...                              ...
# 120717                        -99999
# 120744                        -99999
# 120763                        -99999
# 120787                        -99999
# 120814                        -99999
#
# [3610 rows x 18 columns]

# %% [markdown]
# **Filtros Mais Complexos**

# %%
estado_rj_sp = (data["ESTADO"] == "SAO PAULO") | (data["ESTADO"] == "RIO DE JANEIRO")
gasolina_maior_que_2 = (data["PRODUTO"] == "GASOLINA COMUM") & (data["PREÇO MÉDIO REVENDA"] > 2)
data[estado_rj_sp & gasolina_maior_que_2]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    09/05/2004  15/05/2004  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    16/05/2004  22/05/2004  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    23/05/2004  29/05/2004  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    30/05/2004  05/06/2004  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    06/06/2004  12/06/2004  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 120366   11/04/2021  17/04/2021  SUDESTE       SAO PAULO  GASOLINA COMUM
# 120538   18/04/2021  24/04/2021  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 120544   18/04/2021  24/04/2021  SUDESTE       SAO PAULO  GASOLINA COMUM
# 120717   25/04/2021  01/05/2021  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 120723   25/04/2021  01/05/2021  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12113                           1055              R$/l                2.040
# 12140                           1091              R$/l                2.042
# 12167                           1055              R$/l                2.053
# 12194                           1091              R$/l                2.063
# ...                              ...               ...                  ...
# 120366                          1058              R$/l                5.206
# 120538                           240              R$/l                6.071
# 120544                          1075              R$/l                5.205
# 120717                           198              R$/l                6.099
# 120723                          1187              R$/l                5.265
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 12086                   0.109                 1.700                 2.599
# 12113                   0.113                 1.700                 2.599
# 12140                   0.108                 1.700                 2.599
# 12167                   0.111                 1.730                 2.599
# 12194                   0.107                 1.760                 2.599
# ...                       ...                   ...                   ...
# 120366                  0.234                 3.899                 5.999
# 120538                  0.217                 5.399                 6.599
# 120544                  0.216                 4.199                 5.999
# 120717                  0.208                 5.480                 6.599
# 120723                  0.218                 4.279                 6.099
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 12086                 0.254                     0.053
# 12113                 0.252                     0.055
# 12140                 0.252                     0.053
# 12167                 0.251                     0.054
# 12194                 0.247                     0.052
# ...                     ...                       ...
# 120366               -99999                     0.045
# 120538               -99999                     0.036
# 120544               -99999                     0.041
# 120717               -99999                     0.034
# 120723               -99999                     0.041
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12086                     1.791                      0.047
# 12113                     1.788                      0.049
# 12140                      1.79                      0.046
# 12167                     1.802                      0.055
# 12194                     1.816                      0.054
# ...                         ...                        ...
# 120366                   -99999                     -99999
# 120538                   -99999                     -99999
# 120544                   -99999                     -99999
# 120717                   -99999                     -99999
# 120723                   -99999                     -99999
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12086                     1.6363                    1.9594
# 12113                     1.5943                   1.99651
# 12140                    1.63596                    2.2137
# 12167                       1.64                   2.21425
# 12194                       1.64                   2.32425
# ...                          ...                       ...
# 120366                    -99999                    -99999
# 120538                    -99999                    -99999
# 120544                    -99999                    -99999
# 120717                    -99999                    -99999
# 120723                    -99999                    -99999
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 12086                          0.026
# 12113                          0.027
# 12140                          0.026
# 12167                          0.031
# 12194                           0.03
# ...                              ...
# 120366                        -99999
# 120538                        -99999
# 120544                        -99999
# 120717                        -99999
# 120723                        -99999
#
# [1740 rows x 18 columns]

# %%
estado_rj_sp = (data["ESTADO"] == "SAO PAULO") | (data["ESTADO"] == "RIO DE JANEIRO")
postos_sp_rj = data[estado_rj_sp]

# %%
gasolina_maior_que_2 = (postos_sp_rj["PRODUTO"] == "GASOLINA COMUM") & (postos_sp_rj["PREÇO MÉDIO REVENDA"] > 2)

# %%
postos_sp_rj_gasolina_maior_que_2 = postos_sp_rj[gasolina_maior_que_2]

# %%
postos_sp_rj_gasolina_maior_que_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    09/05/2004  15/05/2004  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    16/05/2004  22/05/2004  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    23/05/2004  29/05/2004  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    30/05/2004  05/06/2004  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    06/06/2004  12/06/2004  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 120366   11/04/2021  17/04/2021  SUDESTE       SAO PAULO  GASOLINA COMUM
# 120538   18/04/2021  24/04/2021  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 120544   18/04/2021  24/04/2021  SUDESTE       SAO PAULO  GASOLINA COMUM
# 120717   25/04/2021  01/05/2021  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 120723   25/04/2021  01/05/2021  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12113                           1055              R$/l                2.040
# 12140                           1091              R$/l                2.042
# 12167                           1055              R$/l                2.053
# 12194                           1091              R$/l                2.063
# ...                              ...               ...                  ...
# 120366                          1058              R$/l                5.206
# 120538                           240              R$/l                6.071
# 120544                          1075              R$/l                5.205
# 120717                           198              R$/l                6.099
# 120723                          1187              R$/l                5.265
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 12086                   0.109                 1.700                 2.599
# 12113                   0.113                 1.700                 2.599
# 12140                   0.108                 1.700                 2.599
# 12167                   0.111                 1.730                 2.599
# 12194                   0.107                 1.760                 2.599
# ...                       ...                   ...                   ...
# 120366                  0.234                 3.899                 5.999
# 120538                  0.217                 5.399                 6.599
# 120544                  0.216                 4.199                 5.999
# 120717                  0.208                 5.480                 6.599
# 120723                  0.218                 4.279                 6.099
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 12086                 0.254                     0.053
# 12113                 0.252                     0.055
# 12140                 0.252                     0.053
# 12167                 0.251                     0.054
# 12194                 0.247                     0.052
# ...                     ...                       ...
# 120366               -99999                     0.045
# 120538               -99999                     0.036
# 120544               -99999                     0.041
# 120717               -99999                     0.034
# 120723               -99999                     0.041
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12086                     1.791                      0.047
# 12113                     1.788                      0.049
# 12140                      1.79                      0.046
# 12167                     1.802                      0.055
# 12194                     1.816                      0.054
# ...                         ...                        ...
# 120366                   -99999                     -99999
# 120538                   -99999                     -99999
# 120544                   -99999                     -99999
# 120717                   -99999                     -99999
# 120723                   -99999                     -99999
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12086                     1.6363                    1.9594
# 12113                     1.5943                   1.99651
# 12140                    1.63596                    2.2137
# 12167                       1.64                   2.21425
# 12194                       1.64                   2.32425
# ...                          ...                       ...
# 120366                    -99999                    -99999
# 120538                    -99999                    -99999
# 120544                    -99999                    -99999
# 120717                    -99999                    -99999
# 120723                    -99999                    -99999
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 12086                          0.026
# 12113                          0.027
# 12140                          0.026
# 12167                          0.031
# 12194                           0.03
# ...                              ...
# 120366                        -99999
# 120538                        -99999
# 120544                        -99999
# 120717                        -99999
# 120723                        -99999
#
# [1740 rows x 18 columns]

# %% [markdown]
# **Função isin()**

# %%
estados = ["PIAUI", "TOCANTINS", "SANTA CATARINA"]
selec = data["ESTADO"].isin(estados) ## ~Leia~ algum estado de estados isin "ESTADO"?

# %%
data[selec]
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO          ESTADO           PRODUTO  \
# 10       09/05/2004  15/05/2004  NORDESTE           PIAUI  ETANOL HIDRATADO
# 19       09/05/2004  15/05/2004     NORTE       TOCANTINS  ETANOL HIDRATADO
# 26       09/05/2004  15/05/2004       SUL  SANTA CATARINA  ETANOL HIDRATADO
# 37       16/05/2004  22/05/2004  NORDESTE           PIAUI  ETANOL HIDRATADO
# 46       16/05/2004  22/05/2004     NORTE       TOCANTINS  ETANOL HIDRATADO
# ...             ...         ...       ...             ...               ...
# 120792   25/04/2021  01/05/2021       SUL  SANTA CATARINA       OLEO DIESEL
# 120795   25/04/2021  01/05/2021     NORTE       TOCANTINS       OLEO DIESEL
# 120813   25/04/2021  01/05/2021  NORDESTE           PIAUI   OLEO DIESEL S10
# 120819   25/04/2021  01/05/2021       SUL  SANTA CATARINA   OLEO DIESEL S10
# 120822   25/04/2021  01/05/2021     NORTE       TOCANTINS   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 10                                89              R$/l                1.573
# 19                                71              R$/l                1.226
# 26                               506              R$/l                1.229
# 37                                93              R$/l                1.571
# 46                                71              R$/l                1.227
# ...                              ...               ...                  ...
# 120792                            61              R$/l                4.064
# 120795                            13              R$/l                4.358
# 120813                            36              R$/l                4.382
# 120819                           100              R$/l                4.141
# 120822                            18              R$/l                4.352
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 10                      0.134                 1.400                 1.780
# 19                      0.081                 1.050                 1.430
# 26                      0.077                 0.999                 1.460
# 37                      0.133                 1.350                 1.780
# 46                      0.084                 1.050                 1.430
# ...                       ...                   ...                   ...
# 120792                  0.206                 3.849                 4.766
# 120795                  0.160                 4.180                 4.599
# 120813                  0.172                 3.999                 4.897
# 120819                  0.187                 3.838                 4.739
# 120822                  0.156                 4.199                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 10                    0.494                     0.085
# 19                    0.546                     0.066
# 26                    0.416                     0.063
# 37                    0.489                     0.085
# 46                    0.529                     0.068
# ...                     ...                       ...
# 120792               -99999                     0.051
# 120795               -99999                     0.037
# 120813               -99999                     0.039
# 120819               -99999                     0.045
# 120822               -99999                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 10                        1.079                      0.078
# 19                         0.68                      0.114
# 26                        0.813                      0.097
# 37                        1.082                      0.094
# 46                        0.698                      0.117
# ...                         ...                        ...
# 120792                   -99999                     -99999
# 120795                   -99999                     -99999
# 120813                   -99999                     -99999
# 120819                   -99999                     -99999
# 120822                   -99999                     -99999
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 10                        0.8857                    1.2499
# 19                       0.51022                     1.035
# 26                          0.57                    1.2348
# 37                        0.8678                    1.2499
# 46                         0.529                    0.9832
# ...                          ...                       ...
# 120792                    -99999                    -99999
# 120795                    -99999                    -99999
# 120813                    -99999                    -99999
# 120819                    -99999                    -99999
# 120822                    -99999                    -99999
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 10                             0.072
# 19                             0.168
# 26                             0.119
# 37                             0.087
# 46                             0.168
# ...                              ...
# 120792                        -99999
# 120795                        -99999
# 120813                        -99999
# 120819                        -99999
# 120822                        -99999
#
# [12788 rows x 18 columns]

# %%
data.query("ESTADO in @estados")
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO          ESTADO           PRODUTO  \
# 10       09/05/2004  15/05/2004  NORDESTE           PIAUI  ETANOL HIDRATADO
# 19       09/05/2004  15/05/2004     NORTE       TOCANTINS  ETANOL HIDRATADO
# 26       09/05/2004  15/05/2004       SUL  SANTA CATARINA  ETANOL HIDRATADO
# 37       16/05/2004  22/05/2004  NORDESTE           PIAUI  ETANOL HIDRATADO
# 46       16/05/2004  22/05/2004     NORTE       TOCANTINS  ETANOL HIDRATADO
# ...             ...         ...       ...             ...               ...
# 120792   25/04/2021  01/05/2021       SUL  SANTA CATARINA       OLEO DIESEL
# 120795   25/04/2021  01/05/2021     NORTE       TOCANTINS       OLEO DIESEL
# 120813   25/04/2021  01/05/2021  NORDESTE           PIAUI   OLEO DIESEL S10
# 120819   25/04/2021  01/05/2021       SUL  SANTA CATARINA   OLEO DIESEL S10
# 120822   25/04/2021  01/05/2021     NORTE       TOCANTINS   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 10                                89              R$/l                1.573
# 19                                71              R$/l                1.226
# 26                               506              R$/l                1.229
# 37                                93              R$/l                1.571
# 46                                71              R$/l                1.227
# ...                              ...               ...                  ...
# 120792                            61              R$/l                4.064
# 120795                            13              R$/l                4.358
# 120813                            36              R$/l                4.382
# 120819                           100              R$/l                4.141
# 120822                            18              R$/l                4.352
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 10                      0.134                 1.400                 1.780
# 19                      0.081                 1.050                 1.430
# 26                      0.077                 0.999                 1.460
# 37                      0.133                 1.350                 1.780
# 46                      0.084                 1.050                 1.430
# ...                       ...                   ...                   ...
# 120792                  0.206                 3.849                 4.766
# 120795                  0.160                 4.180                 4.599
# 120813                  0.172                 3.999                 4.897
# 120819                  0.187                 3.838                 4.739
# 120822                  0.156                 4.199                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 10                    0.494                     0.085
# 19                    0.546                     0.066
# 26                    0.416                     0.063
# 37                    0.489                     0.085
# 46                    0.529                     0.068
# ...                     ...                       ...
# 120792               -99999                     0.051
# 120795               -99999                     0.037
# 120813               -99999                     0.039
# 120819               -99999                     0.045
# 120822               -99999                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 10                        1.079                      0.078
# 19                         0.68                      0.114
# 26                        0.813                      0.097
# 37                        1.082                      0.094
# 46                        0.698                      0.117
# ...                         ...                        ...
# 120792                   -99999                     -99999
# 120795                   -99999                     -99999
# 120813                   -99999                     -99999
# 120819                   -99999                     -99999
# 120822                   -99999                     -99999
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 10                        0.8857                    1.2499
# 19                       0.51022                     1.035
# 26                          0.57                    1.2348
# 37                        0.8678                    1.2499
# 46                         0.529                    0.9832
# ...                          ...                       ...
# 120792                    -99999                    -99999
# 120795                    -99999                    -99999
# 120813                    -99999                    -99999
# 120819                    -99999                    -99999
# 120822                    -99999                    -99999
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 10                             0.072
# 19                             0.168
# 26                             0.119
# 37                             0.087
# 46                             0.168
# ...                              ...
# 120792                        -99999
# 120795                        -99999
# 120813                        -99999
# 120819                        -99999
# 120822                        -99999
#
# [12788 rows x 18 columns]

# %% [markdown]
# ##### **Iterando DataFrames**

# %% [markdown]
# For-each `DataFrame.iterrows()`
# - Lento, apenas indicado para pequenos conjunto de dados

# %%
for index, row in data.head(20).iterrows():
    print(f"indice {index} => {row['ESTADO']}")
# Out:
# indice 0 => DISTRITO FEDERAL
# indice 1 => GOIAS
# indice 2 => MATO GROSSO
# indice 3 => MATO GROSSO DO SUL
# indice 4 => ALAGOAS
# indice 5 => BAHIA
# indice 6 => CEARA
# indice 7 => MARANHAO
# indice 8 => PARAIBA
# indice 9 => PERNAMBUCO
# indice 10 => PIAUI
# indice 11 => RIO GRANDE DO NORTE
# indice 12 => SERGIPE
# indice 13 => ACRE
# indice 14 => AMAPA
# indice 15 => AMAZONAS
# indice 16 => PARA
# indice 17 => RONDONIA
# indice 18 => RORAIMA
# indice 19 => TOCANTINS
