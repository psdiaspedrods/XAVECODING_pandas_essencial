# %% [markdown]
# # Agrupamentos

# %%
import pandas as pd

# %%
data = pd.read_csv('./datasets/gas_prices_brazil_2004-2021_pre.csv')

# %% [markdown]
# `groupby`: Usado para criar **grupos de elementos** (e.x., baseado nos valores de um atributo (categórico)). <br/>
# **Funções** podem então ser aplicadas para os _elementos de cada grupo_, de modo que os **resultados de cada grupo são combinados**.

# %%
# agrupa as linhas da tabela de acordo com suas respectivas regiões
grupos = data.groupby("REGIÃO")
grupos

# %%
# retorna os grupos obtidos pelo groupby
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14,
# ...

# %%
# retorna os índices das linhas/observações de cada grupo
grupos.indices
# Out:
# {'CENTRO OESTE': array([     0,      1,      2, ..., 117373, 117375, 117376]),
#  'NORDESTE': array([     4,      5,      6, ..., 117382, 117384, 117390]),
#  'NORTE': array([    13,     14,     15, ..., 117386, 117387, 117391]),
#  'SUDESTE': array([    20,     21,     22, ..., 117377, 117383, 117389]),
#  'SUL': array([    24,     25,     26, ..., 117380, 117385, 117388])}

# %%
# retorna um dataframe apenas com as observações do grupo especificado
grupos.get_group("CENTRO OESTE")
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 27       2004-05-16  2004-05-22  CENTRO OESTE    DISTRITO FEDERAL
# ...             ...         ...           ...                 ...
# 117349   2021-04-25  2021-05-01  CENTRO OESTE  MATO GROSSO DO SUL
# 117371   2021-04-25  2021-05-01  CENTRO OESTE    DISTRITO FEDERAL
# 117373   2021-04-25  2021-05-01  CENTRO OESTE               GOIAS
# 117375   2021-04-25  2021-05-01  CENTRO OESTE         MATO GROSSO
# 117376   2021-04-25  2021-05-01  CENTRO OESTE  MATO GROSSO DO SUL
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
# descreva para nós algumas estatística descritivas para as observações de cada grupo
grupos.describe()
# Out:
#              NÚMERO DE POSTOS PESQUISADOS                                      \
#                                     count        mean         std  min    25%
# REGIÃO
# CENTRO OESTE                      16565.0  137.275521  103.448516  1.0   76.0
# NORDESTE                          40590.0  118.363439  110.578621  1.0   38.0
# NORTE                             27287.0   64.003921   51.745055  1.0   28.0
# SUDESTE                           18967.0  684.316655  763.338730  1.0  146.0
# SUL                               13983.0  343.313738  231.843167  1.0  150.0
#
#                                    PREÇO MÉDIO REVENDA             ...  \
#                 50%    75%     max               count       mean  ...
# REGIÃO                                                             ...
# CENTRO OESTE  118.0  176.0   766.0             16565.0  12.873181  ...
# NORDESTE       84.0  153.0   625.0             40590.0  10.202962  ...
# ...

# %%
grupos.min()
# Out:
#              DATA INICIAL  DATA FINAL            ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE   2004-05-09  2004-05-15  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE       2004-05-09  2004-05-15           ALAGOAS  ETANOL HIDRATADO
# NORTE          2004-05-09  2004-05-15              ACRE  ETANOL HIDRATADO
# SUDESTE        2004-05-09  2004-05-15    ESPIRITO SANTO  ETANOL HIDRATADO
# SUL            2004-05-09  2004-05-15            PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE                1.097                    0.0
# ...

# %%
data.groupby('REGIÃO').min()
# Out:
#              DATA INICIAL  DATA FINAL            ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE   2004-05-09  2004-05-15  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE       2004-05-09  2004-05-15           ALAGOAS  ETANOL HIDRATADO
# NORTE          2004-05-09  2004-05-15              ACRE  ETANOL HIDRATADO
# SUDESTE        2004-05-09  2004-05-15    ESPIRITO SANTO  ETANOL HIDRATADO
# SUL            2004-05-09  2004-05-15            PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE                1.097                    0.0
# ...

# %% [markdown]
# **Agrupando os Agrupamentos**

# %%
grupos_regioes = data.groupby(["REGIÃO", "PRODUTO"])
grupos_regioes

# %%
 grupos_regioes.groups
# Out:
# {('CENTRO OESTE', 'ETANOL HIDRATADO'): [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], ('CENTRO OESTE', 'GASOLINA ADITIVADA'): [112484, 112486, 112488, 112489, 112659, 112661, 112663, 112664, 112832, 112834, 112836, 112837, 113007, 113009, 113011, 113012, 113184, 113186, 113188, 113189, 113360, 113362, 113364, 113365, 113534, 113536, 113538, 113539, 113708, 113710, 113712, 113713, 113882, 113884, 113886, 113887, 114054, 114056, 114058, 114059, 114231, 114233, 114235, 114236, 114405, 114407, 114409, 114410, 114580, 114582, 114584, 114585, 114756, 114758,
# ...

# %%
grupos_regioes.max()
# Out:
#                                 DATA INICIAL  DATA FINAL              ESTADO  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO     2021-04-25  2021-05-01  MATO GROSSO DO SUL
#              GASOLINA ADITIVADA   2021-04-25  2021-05-01  MATO GROSSO DO SUL
#              GASOLINA COMUM       2021-04-25  2021-05-01  MATO GROSSO DO SUL
#              GLP                  2021-04-25  2021-05-01  MATO GROSSO DO SUL
#              GNV                  2021-04-25  2021-05-01  MATO GROSSO DO SUL
#              OLEO DIESEL          2021-04-25  2021-05-01  MATO GROSSO DO SUL
#              OLEO DIESEL S10      2021-04-25  2021-05-01  MATO GROSSO DO SUL
#              ÓLEO DIESEL          2019-06-23  2019-06-29  MATO GROSSO DO SUL
#              ÓLEO DIESEL S10      2019-06-23  2019-06-29  MATO GROSSO DO SUL
# NORDESTE     ETANOL HIDRATADO     2021-04-25  2021-05-01             SERGIPE
#              GASOLINA ADITIVADA   2021-04-25  2021-05-01             SERGIPE
# ...

# %% [markdown]
# <br/>
#
# `.agg`: **agrega (roda)** uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [None, None, None]],
                  columns=['A', 'B', 'C'])
df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
df.agg([sum, min])  # ignora o NaN
# Out:
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
# Computa o menor e maior valor do 'PREÇO MÉDIO REVENDA' para cada região (grupo)
grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# Out:
#                 min      max
# REGIÃO
# CENTRO OESTE  1.097  105.194
# NORDESTE      0.975   91.725
# NORTE         1.226  107.500
# SUDESTE       0.766   87.091
# SUL           0.922   91.189
